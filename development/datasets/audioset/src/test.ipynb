# %% [markdown]
# # First configurations

# %%
import glob
import tensorflow as tf
import numpy as np

# %%
FEATURES_PATH = "/home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train"
BATCH_SIZE = 32

# %% [markdown]
# # Load the AudioSet Dataset

# %%
# Get a list of all TFRecord files in a directory
tfrecord_files = glob.glob(f"{FEATURES_PATH}/*.tfrecord")

# Load all TFRecord files into a single dataset
dataset = tf.data.TFRecordDataset(tfrecord_files).batch(BATCH_SIZE)
# Out:
# 2023-07-28 12:37:18.606550: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# # Pass to pytorch

# %%
import tensorflow as tf

# Constants
FEATURES_PATH = "/home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train"

# Function to read and print feature keys from TFRecord files
def inspect_feature_keys(tfrecord_file):
    for record in tf.data.TFRecordDataset(tfrecord_file):
        example = tf.train.Example()
        example.ParseFromString(record.numpy())
        
        # Print the feature keys for each example
        print(list(example.features.feature.keys()))

# Get a list of all TFRecord files in the directory
tfrecord_files = tf.io.gfile.glob(f"{FEATURES_PATH}/*.tfrecord")

# Loop through each TFRecord file and inspect the feature keys
for file in tfrecord_files:
    print(f"Inspecting file: {file}")
    inspect_feature_keys(file)
    print()
# Out:
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/YH.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Oi.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/IE.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/eM.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/dv.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/oZ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/tC.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/oY.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/pG.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/3y.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/kC.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Nn.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/9H.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/s_.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/wR.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/QT.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/EC.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Ci.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Sl.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Qh.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/fK.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Be.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/vM.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/L4.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/fD.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/4K.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/w8.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Kj.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/4f.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/GZ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/nM.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/W4.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/7I.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/-7.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/lD.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/W5.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/VY.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/IW.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Sm.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/SY.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/3n.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/xy.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/QQ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Zv.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/X6.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/GS.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/e9.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/an.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/IJ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Jd.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Wh.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/ga.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/90.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/KC.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Xw.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/R3.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Pv.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Hn.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Wn.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/nb.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/jx.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/H8.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/PR.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/MO.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/ub.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/YP.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/_-.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/84.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/b3.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/0B.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/3S.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/OV.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/mU.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/__.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/wr.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/_N.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/l8.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/yN.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/bp.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/1F.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/-b.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/9v.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/uh.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/yt.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/cq.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/3b.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/M7.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/20.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/vh.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/rE.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/so.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/IQ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/BS.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/yG.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Rq.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ...
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/70.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/zq.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/G9.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/NZ.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/e4.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/G0.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/pY.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/qu.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/zu.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/XC.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Ul.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/XO.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/nx.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/sj.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/5W.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Xj.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/s2.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/UH.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/0i.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/LK.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/69.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/i9.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/wP.tfrecord
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/md.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/k6.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Ge.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Li.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/Yq.tfrecord
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['labels', 'video_id', 'start_time_seconds', 'end_time_seconds']
# ['end_time_seconds', 'video_id', 'start_time_seconds', 'labels']
#
# Inspecting file: /home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train/te.tfrecord
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 21
#      19 for file in tfrecord_files:
#      20     print(f"Inspecting file: {file}")
# ---> 21     inspect_feature_keys(file)
#      22     print()
#
# Cell In[18], line 8, in inspect_feature_keys(tfrecord_file)
#       7 def inspect_feature_keys(tfrecord_file):
# ----> 8     for record in tf.data.TFRecordDataset(tfrecord_file):
#       9         example = tf.train.Example()
#      10         example.ParseFromString(record.numpy())
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Convert to pytorch tensors

# %%
import tensorflow as tf
import torch
import h5py
import glob

# Constants
FEATURES_PATH = "/home/admin/FEUP-Synthesizing-Audio-from-Textual-Input/audioset/data/features/audioset_v1_embeddings/bal_train"
BATCH_SIZE = 32

# Get a list of all TFRecord files in a directory
tfrecord_files = glob.glob(f"{FEATURES_PATH}/*.tfrecord")

# Helper function to parse the TFRecord example and convert to TensorFlow tensors
def parse_example(example):
    feature_description = {
        # Replace these keys with the actual feature keys
        'labels': tf.io.FixedLenFeature([], tf.int64),
        'video_id': tf.io.FixedLenFeature([], tf.string),
        'start_time_seconds': tf.io.FixedLenFeature([], tf.float32),
        'end_time_seconds': tf.io.FixedLenFeature([], tf.float32),
    }
    example = tf.io.parse_single_example(example, feature_description)
    
    return (
        example['labels'],
        example['video_id'],
        example['start_time_seconds'],
        example['end_time_seconds']
        # Add more tensors if you have more features
    )

# Load all TFRecord files into a single dataset
dataset = tf.data.TFRecordDataset(tfrecord_files)
dataset = dataset.map(parse_example)
dataset = dataset.batch(BATCH_SIZE)

# Convert TensorFlow tensors to a list of PyTorch tensors
tensor_list = [(torch.tensor(labels.numpy(), dtype=torch.int64),
                video_id.numpy().decode('utf-8'),
                torch.tensor(start_time.numpy(), dtype=torch.float32),
                torch.tensor(end_time.numpy(), dtype=torch.float32)) for labels, video_id, start_time, end_time in dataset]
# Out:
# 2023-07-28 13:00:24.256808: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.256889: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.256966: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.257040: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.257978: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258018: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258047: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258084: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258123: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258163: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258849: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.258904: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.259678: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.259721: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.259756: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.259774: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.260328: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.260369: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# 2023-07-28 13:00:24.260400: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at example_parsing_ops.cc:98 : INVALID_ARGUMENT: Key: labels.  Can't parse serialized Example.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[25], line 38
#      35 dataset = dataset.batch(BATCH_SIZE)
#      37 # Convert TensorFlow tensors to a list of PyTorch tensors
# ---> 38 tensor_list = [(torch.tensor(labels.numpy(), dtype=torch.int64),
#      39                 video_id.numpy().decode('utf-8'),
#      40                 torch.tensor(start_time.numpy(), dtype=torch.float32),
#      41                 torch.tensor(end_time.numpy(), dtype=torch.float32)) for labels, video_id, start_time, end_time in dataset]
#
# Cell In[25], line 38, in <listcomp>(.0)
#      35 dataset = dataset.batch(BATCH_SIZE)
#      37 # Convert TensorFlow tensors to a list of PyTorch tensors
# ---> 38 tensor_list = [(torch.tensor(labels.numpy(), dtype=torch.int64),
#      39                 video_id.numpy().decode('utf-8'),
#      40                 torch.tensor(start_time.numpy(), dtype=torch.float32),
#      41                 torch.tensor(end_time.numpy(), dtype=torch.float32)) for labels, video_id, start_time, end_time in dataset]
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:814, in OwnedIterator.__next__(self)
#     812 def __next__(self):
#     813   try:
# --> 814     return self._next_internal()
#     815   except errors.OutOfRangeError:
#     816     raise StopIteration
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:777, in OwnedIterator._next_internal(self)
#     774 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     775 # to communicate that there is no more data to iterate over.
#     776 with context.execution_mode(context.SYNC):
# --> 777   ret = gen_dataset_ops.iterator_get_next(
#     778       self._iterator_resource,
#     779       output_types=self._flat_output_types,
#     780       output_shapes=self._flat_output_shapes)
#     782   try:
#     783     # Fast path for the case `self._structure` is not a nested structure.
#     784     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3028, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3026   return _result
#    3027 except _core._NotOkStatusException as e:
# -> 3028   _ops.raise_from_not_ok_status(e, name)
#    3029 except _core._FallbackException:
#    3030   pass
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6656, in raise_from_not_ok_status(e, name)
#    6654 def raise_from_not_ok_status(e, name):
#    6655   e.message += (" name: " + str(name if name is not None else ""))
# -> 6656   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__IteratorGetNext_output_types_4_device_/job:localhost/replica:0/task:0/device:CPU:0}} Key: labels.  Can't parse serialized Example.
# 	 [[{{node ParseSingleExample/ParseExample/ParseExampleV2}}]] [Op:IteratorGetNext] name:

# %%
# After creating the dataset, add debugging mode
dataset = dataset.apply(tf.data.experimental.enable_debug_mode())

# Then continue with the rest of the code
dataset = dataset.batch(BATCH_SIZE)
tensor_list = [(torch.tensor(labels.numpy(), dtype=torch.int64),
                video_id.numpy().decode('utf-8'),
                torch.tensor(start_time.numpy(), dtype=torch.float32),
                torch.tensor(end_time.numpy(), dtype=torch.float32)) for labels, video_id, start_time, end_time in dataset]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # After creating the dataset, add debugging mode
# ----> 2 dataset = dataset.apply(tf.data.experimental.enable_debug_mode())
#       4 # Then continue with the rest of the code
#       5 dataset = dataset.batch(BATCH_SIZE)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:2519, in DatasetV2.apply(self, transformation_func)
#    2498 def apply(self, transformation_func):
#    2499   """Applies a transformation function to this dataset.
#    2500
#    2501   `apply` enables chaining of custom `Dataset` transformations, which are
#    (...)
#    2517     A new `Dataset` with the transformation applied as described above.
#    2518   """
# -> 2519   dataset = transformation_func(self)
#    2520   if not isinstance(dataset, data_types.DatasetV2):
#    2521     raise TypeError(
#    2522         f"`transformation_func` must return a `tf.data.Dataset` object. "
#    2523         f"Got {type(dataset)}.")
#
# TypeError: 'NoneType' object is not callable
